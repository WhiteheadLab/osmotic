# %%
import pandas as pd
import os
from itertools import izip

# %%
# !pwd
# Out:
# /home/ljcohen/osmotic_salmon

# %%
salmon_dir="/home/ljcohen/osmotic_salmon/"
annotation_dir="/home/ljcohen/msu_assemblies_finished/"

# %%
dirnames=os.listdir(salmon_dir)

# %%
print(dirnames)
# Out:
# ['A_xenica', 'F_sciadicus', 'F_parvapinis', 'F_notti', 'F_heteroclitus.MDPP', 'F_similis', 'F_zebrinus', 'F_chrysotus', 'F_heteroclitus.MDPL', 'F_olivaceous', 'F_grandis', 'F_rathbuni', 'L_parva', 'F_diaphanus', '.ipynb_checkpoints', 'F_notatus', 'GetCounts.ipynb', 'L_goodei', 'F_catanatus']

# %%
def get_annotation_counts(species_annotation_file,counts_data):
    annotation = pd.read_table(species_annotation_file,header=0)
    annotation = annotation.drop(["Start","End","Strand"],axis=1)
    frames = [annotation,counts_data]
    annotated_counts = pd.concat(frames,axis=1,join='inner')
    annotated_counts = annotated_counts.drop(["Chr"],axis=1)
    return annotated_counts

# problem is there are more than 1 transcript ID per GeneID
# Check for uniqueness
# if more than 1:
# if there 0 counts?
# drop 0 counts
# elif more than one transcript ID counted per GeneID?
# then get sum of different transcript ID, same GeneID

def get_unique_annotations(annotated_counts_old):
    # assume rows are sorted, with GeneID and transcriptID adjacent
    # is this a safe assumption?
    # probably not
    # sort
    annotated_itterows = annotated_counts_old.iterrows()
    check_GeneID = ""
    check_transcript = ""
    for i, row in annotated_itterows:
        GeneID = (row['GeneID'])
        transcript = (row['transcript'])
        if GeneID == check_GeneID:
            if row['count'] == 0:
                annotated_counts_old.drop(i)
            elif row['count'] > 0:
                # add counts together
                new_count += count
                # append count value in current row
                annotated_counts_old.set_value(i[1],row['count'], new_count)
                # drop previous row
                annotated_counts_old.drop(previous_i)
        else:
            new_count = 0
        check_GeneID = GeneID
        check_transcript = transcript
        count = row['count']
        previous_row = row
        previous_i = i
    return annotated_counts_old
            
def parse_data(counts_file):
    counts_data=pd.read_table(counts_file,header=0)
    return counts_data
    
def build_DataFrame(counts_dataframe,counts_data):
    counts_dataframe.head()
    counts_data.head()
    counts_dataframe=pd.merge(counts_dataframe,counts_data,on=["GeneID"])
    return counts_dataframe


# get all transcriptID from reference
with open("/home/ljcohen/osmotic/kfish2rae5g.GeneID","rU") as GeneID_file:
    GeneID = pd.read_table(GeneID_file,header=0)
    
counts_dataframe = GeneID

for genus_species in dirnames:
    if genus_species != "GetCounts.ipynb":
        counts_dir = salmon_dir+genus_species
        counts_files = os.listdir(counts_dir)
        species_annotation_dir = annotation_dir+genus_species+"/"
        species_annotation_file = species_annotation_dir+genus_species+".saf"
        print species_annotation_file 
        for filename in counts_files:
            if filename.endswith(".counts"):
                new_filename=filename.split(".")[0]
                counts_file=counts_dir+"/"+filename
                counts_data=parse_data(counts_file)
                annotated_counts = get_annotation_counts(species_annotation_file,counts_data)
                #old_annotation_counts = get_unique_annotations(annotated_counts)
                counts_dataframe=build_DataFrame(counts_dataframe,annotated_counts)
                counts_dataframe.rename(columns = {'count': new_filename},inplace=True)
# Out:
# /home/ljcohen/msu_assemblies_finished/A_xenica/A_xenica.saf

# %%
annotated_counts.head(50)
# Out:
#                GeneID     transcript  count   1   2   4   3   7   5  13 ...  \
# 0   Funhe2EKm036689t1   TR1-c0_g1_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 1   Funhe2EKm036689t1   TR1-c0_g2_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 2   Funhe2EKm000344t1   TR2-c0_g1_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 3   Funhe2EKm038612t1   TR3-c0_g1_i1      1 NaN NaN NaN NaN NaN NaN NaN ...
# 4   Funhe2EKm027593t1   TR4-c0_g1_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 5   Funhe2EKm005246t1   TR5-c0_g1_i1      2 NaN NaN NaN NaN NaN NaN NaN ...
# 6   Funhe2EKm005030t1   TR6-c0_g1_i1      2 NaN NaN NaN NaN NaN NaN NaN ...
# 7   Funhe2EKm030545t1   TR7-c0_g1_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 8   Funhe2EKm035894t1   TR8-c0_g1_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 9   Funhe2EKm024719t1   TR9-c0_g1_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 10  Funhe2EKm031453t1  TR10-c0_g1_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 11  Funhe2EKm035581t1  TR11-c0_g1_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 12  Funhe2EKm006251t1  TR12-c0_g1_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 13  Funhe2EKm038480t1  TR13-c0_g1_i1      2 NaN NaN NaN NaN NaN NaN NaN ...
# 14  Funhe2EKm010535t1  TR14-c0_g1_i1      1 NaN NaN NaN NaN NaN NaN NaN ...
# 15  Funhe2EKm029293t1  TR15-c0_g1_i1      2 NaN NaN NaN NaN NaN NaN NaN ...
# 16  Funhe2EKm026525t1  TR16-c0_g1_i1      1 NaN NaN NaN NaN NaN NaN NaN ...
# 17  Funhe2EKm027029t1  TR17-c0_g1_i1      4 NaN NaN NaN NaN NaN NaN NaN ...
# 18  Funhe2EKm035964t1  TR18-c0_g1_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 19  Funhe2EKm039919t1  TR19-c0_g1_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 20  Funhe2EKm031012t1  TR20-c0_g1_i1      2 NaN NaN NaN NaN NaN NaN NaN ...
# 21  Funhe2EKm039737t1  TR21-c0_g1_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 22  Funhe2EKm028037t1  TR22-c0_g1_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 23  Funhe2EKm032943t1  TR23-c0_g1_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 24  Funhe2EKm034293t1  TR24-c0_g1_i1      1 NaN NaN NaN NaN NaN NaN NaN ...
# 25  Funhe2EKm010358t1  TR25-c0_g1_i1      1 NaN NaN NaN NaN NaN NaN NaN ...
# 26  Funhe2EKm032767t1  TR26-c0_g1_i1      2 NaN NaN NaN NaN NaN NaN NaN ...
# 27  Funhe2EKm029775t1  TR27-c0_g1_i1      4 NaN NaN NaN NaN NaN NaN NaN ...
# 28  Funhe2EKm022939t1  TR28-c0_g1_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 29  Funhe2EKm033123t1  TR29-c0_g1_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 30  Funhe2EKm034983t1  TR30-c0_g1_i1      1 NaN NaN NaN NaN NaN NaN NaN ...
# 31  Funhe2EKm009276t1  TR31-c0_g1_i1      1 NaN NaN NaN NaN NaN NaN NaN ...
# 32  Funhe2EKm014658t1  TR32-c0_g1_i1      2 NaN NaN NaN NaN NaN NaN NaN ...
# 33  Funhe2EKm014658t1  TR33-c0_g1_i1      1   2 NaN NaN NaN NaN NaN NaN ...
# 34  Funhe2EKm023098t1  TR34-c0_g1_i1      1 NaN NaN NaN NaN NaN NaN NaN ...
# 35  Funhe2EKm000844t1  TR35-c0_g1_i1      1 NaN NaN NaN NaN NaN NaN NaN ...
# 36  Funhe2EKm029787t1  TR36-c0_g1_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 37  Funhe2EKm010270t1  TR37-c0_g1_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 38  Funhe2EKm015997t1  TR38-c0_g1_i1      1 NaN NaN NaN NaN NaN NaN NaN ...
# 39  Funhe2EKm028259t1  TR38-c0_g2_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 40  Funhe2EKm033313t1  TR39-c0_g1_i1      2 NaN NaN NaN NaN NaN NaN NaN ...
# 41  Funhe2EKm013666t1  TR40-c0_g1_i1      1 NaN NaN NaN NaN NaN NaN NaN ...
# 42  Funhe2EKm000335t1  TR41-c0_g1_i1      1 NaN NaN NaN NaN NaN NaN NaN ...
# 43  Funhe2EKm002799t1  TR42-c0_g1_i1      2 NaN NaN NaN NaN NaN NaN NaN ...
# 44  Funhe2EKm010067t1  TR43-c0_g1_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 45  Funhe2EKm033123t1  TR44-c0_g1_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 46  Funhe2EKm011028t1  TR45-c0_g1_i1      3 NaN NaN NaN NaN NaN NaN NaN ...
# 47  Funhe2EKm001659t1  TR46-c0_g1_i1      1 NaN NaN NaN NaN NaN NaN NaN ...
# 48  Funhe2EKm038518t1  TR47-c0_g1_i1      0 NaN NaN NaN NaN NaN NaN NaN ...
# 49  Funhe2EKm036352t1  TR48-c0_g1_i1      3 NaN NaN NaN NaN NaN NaN NaN ...
#
#     105  558  1406  853  916  507  530  2681  1732  58
# 0   NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 1   NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 2   NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 3   NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 4   NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 5   NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 6   NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 7   NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 8   NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 9   NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 10  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 11  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 12  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 13  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 14  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 15  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 16  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 17  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 18  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 19  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 20  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 21  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 22  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 23  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 24  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 25  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 26  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 27  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 28  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 29  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 30  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 31  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 32  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 33  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 34  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 35  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 36  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 37  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 38  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 39  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 40  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 41  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 42  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 43  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 44  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 45  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 46  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 47  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 48  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
# 49  NaN  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN
#
# [50 rows x 226 columns]

# %%
counts_dataframe.head()
# Out:
#               GeneID
# 0  Funhe2EKm000003t1
# 1  Funhe2EKm000004t1
# 2  Funhe2EKm000005t1
# 3  Funhe2EKm000006t1
# 4  Funhe2EKm000007t1

# %%
counts_dataframe.to_csv("allcounts.csv")
